# %%
from pycmtensor.utils import CyclicLR
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set_style("ticks")

scheduler = CyclicLR(base_lr=0.01, max_lr=0.1, step_size=10, mode="exp_range", gamma=0.9)
data = []
for i in range(80):
	lr = scheduler.get_lr(i)
	data.append((i, lr))

df = pd.DataFrame(data, columns=["i", "lr"])
sns.lineplot(data=df, x="i", y="lr")
plt.show()
